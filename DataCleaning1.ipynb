# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ###Loading dataset monthwise and selecting 25 busy airports

# %%
import pandas as pd

# %%
filenames = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
filenames_short = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
i=0
for name in filenames:
  path = "/content/drive/My Drive/PROJECT 1001/Data1/" + name + "_dataset.csv"
  df = pd.read_csv(path)
  df = df.loc[df['ORIGIN_CITY_NAME'].isin(['Chicago, IL','Dallas/Fort Worth, TX','New York, NY','Houston, TX','Atlanta, GA',
                                              'Denver, CO','Charlotte, NC','Boston, MA','Washington, DC','Newark, NJ','Los Angeles, CA',
                                              'Phoenix, AZ','San Francisco, CA','Seattle, WA','Las Vegas, NV','Philadelphia, PA',
                                              'Orlando, FL','Minneapolis, MN','Detroit, MI','San Diego, CA'])]
  new_name = 'new_'+filenames_short[i]+'.csv'
  i += 1
  df.to_csv(new_name)
  # !cp '$new_name' 'drive/My Drive/PROJECT 1001/Data2/'
